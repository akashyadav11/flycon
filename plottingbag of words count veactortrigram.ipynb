# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cols = ['Classifier', 'Accuracy', 'Time']

# %%
t = pd.read_csv('trigramwithcountvectoriser1.csv')

# %%
t.head()
# Out:
#    Unnamed: 0                    Classifier  Accuracy        Time  \
# 0           0              Ridge Classifier  0.818563  583.438270
# 1           1           Logistic Regression  0.823762  638.188205
# 2           2                    Perceptron  0.757562  188.866507
# 3           3  Passive-Agressive Classifier  0.764577  179.339370
# 4           4   Stochastic Gradient Descent  0.813616  188.282398
#
#                                Classification report
# 0                precision    recall  f1-score   ...
# 1                precision    recall  f1-score   ...
# 2                precision    recall  f1-score   ...
# 3                precision    recall  f1-score   ...
# 4                precision    recall  f1-score   ...

# %%
t.drop([ 'Time','Classification report'], axis=1, inplace=True)

# %%
t.head()
# Out:
#    Unnamed: 0                    Classifier  Accuracy
# 0           0              Ridge Classifier  0.818563
# 1           1           Logistic Regression  0.823762
# 2           2                    Perceptron  0.757562
# 3           3  Passive-Agressive Classifier  0.764577
# 4           4   Stochastic Gradient Descent  0.813616

# %%
t.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
t.head()
# Out:
#                      Classifier  Accuracy
# 0              Ridge Classifier  0.818563
# 1           Logistic Regression  0.823762
# 2                    Perceptron  0.757562
# 3  Passive-Agressive Classifier  0.764577
# 4   Stochastic Gradient Descent  0.813616

# %%
t.drop(t.index[0])
# Out:
#     Unnamed: 0                    Classifier  Accuracy
# 1            1           Logistic Regression  0.823762
# 2            2                    Perceptron  0.757562
# 3            3  Passive-Agressive Classifier  0.764577
# 4            4   Stochastic Gradient Descent  0.813616
# 5            5                     LinearSVC  0.821319
# 6            6            L1 based LinearSVC  0.819252
# 7            7                           KNN  0.718732
# 8            8              Nearest Centroid  0.637815
# 9            9                Multinomial NB  0.797332
# 10          10                  Bernoulli NB  0.793762
# 11          11                      Adaboost  0.702324

# %%
tt=t.sort_values(by='Accuracy', ascending=True)

# %%
t.drop(t.index[0])
# Out:
#                         Classifier            Accuracy
# 0.0               Ridge Classifier  0.8185632867789816
# 1.0            Logistic Regression  0.8237615081104779
# 2.0                     Perceptron   0.757562472599737
# 3.0   Passive-Agressive Classifier  0.7593160894344586
# 4.0    Stochastic Gradient Descent  0.8138660988288344
# 5.0                      LinearSVC  0.8206300494770464
# 6.0             L1 based LinearSVC    0.82138159954907
# 7.0                            KNN  0.7187323855451869
# 8.0               Nearest Centroid  0.6378154944573182
# 9.0                 Multinomial NB  0.7973319972443164
# 10.0                  Bernoulli NB  0.7937621344022046
# 11.0                      Adaboost  0.7023235423060061

# %%
tt
# Out:
#                       Classifier  Accuracy
# 8               Nearest Centroid  0.637815
# 11                      Adaboost  0.702324
# 7                            KNN  0.718732
# 2                     Perceptron  0.757562
# 3   Passive-Agressive Classifier  0.764577
# 10                  Bernoulli NB  0.793762
# 9                 Multinomial NB  0.797332
# 4    Stochastic Gradient Descent  0.813616
# 0               Ridge Classifier  0.818563
# 6             L1 based LinearSVC  0.819252
# 5                      LinearSVC  0.821319
# 1            Logistic Regression  0.823762

# %%
ttt=tt.drop(t.index[0])

# %%
ttt
# Out:
#                         Classifier            Accuracy
# 8.0               Nearest Centroid  0.6378154944573182
# 11.0                      Adaboost  0.7023235423060061
# 7.0                            KNN  0.7187323855451869
# 2.0                     Perceptron   0.757562472599737
# 3.0   Passive-Agressive Classifier  0.7593160894344586
# 10.0                  Bernoulli NB  0.7937621344022046
# 9.0                 Multinomial NB  0.7973319972443164
# 4.0    Stochastic Gradient Descent  0.8138660988288344
# 0.0               Ridge Classifier  0.8185632867789816
# 5.0                      LinearSVC  0.8206300494770464
# 6.0             L1 based LinearSVC    0.82138159954907
# 1.0            Logistic Regression  0.8237615081104779

# %%
plt.bar("Classifier","Accuracy", data =tt, color = "blue")
plt.xlabel("Classifier")
plt.xticks(rotation = 90)
plt.ylabel("Accuracy")
plt.title("Accuracy of bag of words trigram")
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(14,12))
plt.plot("Classifier","Accuracy", data =tt, color = "blue")
plt.xlabel("Classifier")
plt.xticks(rotation = 90)
plt.ylabel("Accuracy")
plt.title("Accuracy of bag of words trigram")
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(14,12))
plt.bar("Classifier","Accuracy", data =tt, color = "blue")
plt.xlabel("Classifier")
plt.xticks(rotation = 90)
plt.ylabel("Accuracy")
plt.title("Accuracy of bag of words trigram")
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(14,12))
plt.bar("Classifier","Accuracy", data =tt, color = "blue")
plt.xlabel("Classifier")
plt.xticks(rotation = 90)
plt.ylabel("Accuracy")
plt.title("Accuracy of bag of words trigram")
plt.show()
