# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=[('Ridge Classifier', 0.8185632867789816, 580.59814620018),
 ('Logistic Regression', 0.8237615081104779, 611.4296820163727),
 ('Perceptron', 0.757562472599737, 750.1953251361847),
 ('Passive-Agressive Classifier', 0.7593160894344586, 186.06019163131714),
 ('Stochastic Gradient Descent', 0.8138660988288344, 183.67948579788208),
 ('LinearSVC', 0.8206300494770464, 827.0392413139343),
 ('L1 based LinearSVC', 0.82138159954907, 1220.1411337852478),
 ('KNN', 0.7187323855451869, 1968.039529800415),
 ('Nearest Centroid', 0.6378154944573182, 287.850460767746),
 ('Multinomial NB', 0.7973319972443164, 251.4556438922882),
 ('Bernoulli NB', 0.7937621344022046, 259.98261547088623),
 ('Adaboost', 0.7023235423060061, 540.1976461410522)]

# %%
data
# Out:
# [('Ridge Classifier', 0.8185632867789816, 580.59814620018),
#  ('Logistic Regression', 0.8237615081104779, 611.4296820163727),
#  ('Perceptron', 0.757562472599737, 750.1953251361847),
#  ('Passive-Agressive Classifier', 0.7593160894344586, 186.06019163131714),
#  ('Stochastic Gradient Descent', 0.8138660988288344, 183.67948579788208),
#  ('LinearSVC', 0.8206300494770464, 827.0392413139343),
#  ('L1 based LinearSVC', 0.82138159954907, 1220.1411337852478),
#  ('KNN', 0.7187323855451869, 1968.039529800415),
#  ('Nearest Centroid', 0.6378154944573182, 287.850460767746),
#  ('Multinomial NB', 0.7973319972443164, 251.4556438922882),
#  ('Bernoulli NB', 0.7937621344022046, 259.98261547088623),
#  ('Adaboost', 0.7023235423060061, 540.1976461410522)]

# %%
labels = ['Classifier', 'Accuracy', 'Time']
df = pd.DataFrame(data, columns = labels)

# %%
df.to_csv('data.csv')

# %%
cols = ['Classifier', 'Accuracy', 'Time']

# %%
t = pd.read_csv('data.csv', header=None, names=cols)

# %%
t.head()
# Out:
#                        Classifier            Accuracy                Time
# NaN                    Classifier            Accuracy                Time
# 0.0              Ridge Classifier  0.8185632867789816     580.59814620018
# 1.0           Logistic Regression  0.8237615081104779   611.4296820163727
# 2.0                    Perceptron   0.757562472599737   750.1953251361847
# 3.0  Passive-Agressive Classifier  0.7593160894344586  186.06019163131714

# %%
t.drop([ 'Time'], axis=1, inplace=True)

# %%
t.head()
# Out:
#                        Classifier            Accuracy
# NaN                    Classifier            Accuracy
# 0.0              Ridge Classifier  0.8185632867789816
# 1.0           Logistic Regression  0.8237615081104779
# 2.0                    Perceptron   0.757562472599737
# 3.0  Passive-Agressive Classifier  0.7593160894344586

# %%
t.drop(t.index[0])
# Out:
#                         Classifier            Accuracy
# 0.0               Ridge Classifier  0.8185632867789816
# 1.0            Logistic Regression  0.8237615081104779
# 2.0                     Perceptron   0.757562472599737
# 3.0   Passive-Agressive Classifier  0.7593160894344586
# 4.0    Stochastic Gradient Descent  0.8138660988288344
# 5.0                      LinearSVC  0.8206300494770464
# 6.0             L1 based LinearSVC    0.82138159954907
# 7.0                            KNN  0.7187323855451869
# 8.0               Nearest Centroid  0.6378154944573182
# 9.0                 Multinomial NB  0.7973319972443164
# 10.0                  Bernoulli NB  0.7937621344022046
# 11.0                      Adaboost  0.7023235423060061

# %%
tt=t.sort_values(by='Accuracy', ascending=True)

# %%
t.drop(t.index[0])
# Out:
#                         Classifier            Accuracy
# 0.0               Ridge Classifier  0.8185632867789816
# 1.0            Logistic Regression  0.8237615081104779
# 2.0                     Perceptron   0.757562472599737
# 3.0   Passive-Agressive Classifier  0.7593160894344586
# 4.0    Stochastic Gradient Descent  0.8138660988288344
# 5.0                      LinearSVC  0.8206300494770464
# 6.0             L1 based LinearSVC    0.82138159954907
# 7.0                            KNN  0.7187323855451869
# 8.0               Nearest Centroid  0.6378154944573182
# 9.0                 Multinomial NB  0.7973319972443164
# 10.0                  Bernoulli NB  0.7937621344022046
# 11.0                      Adaboost  0.7023235423060061

# %%
tt
# Out:
#                         Classifier            Accuracy
# 8.0               Nearest Centroid  0.6378154944573182
# 11.0                      Adaboost  0.7023235423060061
# 7.0                            KNN  0.7187323855451869
# 2.0                     Perceptron   0.757562472599737
# 3.0   Passive-Agressive Classifier  0.7593160894344586
# 10.0                  Bernoulli NB  0.7937621344022046
# 9.0                 Multinomial NB  0.7973319972443164
# 4.0    Stochastic Gradient Descent  0.8138660988288344
# 0.0               Ridge Classifier  0.8185632867789816
# 5.0                      LinearSVC  0.8206300494770464
# 6.0             L1 based LinearSVC    0.82138159954907
# 1.0            Logistic Regression  0.8237615081104779
# NaN                     Classifier            Accuracy

# %%
ttt=tt.drop(t.index[0])

# %%
ttt
# Out:
#                         Classifier            Accuracy
# 8.0               Nearest Centroid  0.6378154944573182
# 11.0                      Adaboost  0.7023235423060061
# 7.0                            KNN  0.7187323855451869
# 2.0                     Perceptron   0.757562472599737
# 3.0   Passive-Agressive Classifier  0.7593160894344586
# 10.0                  Bernoulli NB  0.7937621344022046
# 9.0                 Multinomial NB  0.7973319972443164
# 4.0    Stochastic Gradient Descent  0.8138660988288344
# 0.0               Ridge Classifier  0.8185632867789816
# 5.0                      LinearSVC  0.8206300494770464
# 6.0             L1 based LinearSVC    0.82138159954907
# 1.0            Logistic Regression  0.8237615081104779

# %%
plt.bar("Classifier","Accuracy", data =ttt, color = "blue")
plt.xlabel("Classifier")
plt.xticks(rotation = 90)
plt.ylabel("Accuracy")
plt.title("Accuracy of bag of words trigram")
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(14,12))
plt.plot("Classifier","Accuracy", data =ttt, color = "blue")
plt.xlabel("Classifier")
plt.xticks(rotation = 90)
plt.ylabel("Accuracy")
plt.title("Accuracy of bag of words trigram")
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(14,12))
plt.bar("Classifier","Accuracy", data =ttt, color = "blue")
plt.xlabel("Classifier")
plt.xticks(rotation = 90)
plt.ylabel("Accuracy")
plt.title("Accuracy of bag of words trigram")
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(14,12))
plt.bar("Classifier","Accuracy", data =ttt, color = "blue")
plt.xlabel("Classifier")
plt.xticks(rotation = 90)
plt.ylabel("Accuracy")
plt.title("Accuracy of bag of words trigram")
plt.show()
