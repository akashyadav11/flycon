# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
t = pd.read_csv('bigramwithtfidf1.csv')

# %%
t.head()
# Out:
#    Unnamed: 0                    Classifier  Accuracy        Time  \
# 0           0              Ridge Classifier  0.822759  138.702288
# 1           1           Logistic Regression  0.824263  142.102283
# 2           2                    Perceptron  0.763888   78.635904
# 3           3  Passive-Agressive Classifier  0.799148   79.559549
# 4           4   Stochastic Gradient Descent  0.787437   84.752030
#
#                                Classification report
# 0                precision    recall  f1-score   ...
# 1                precision    recall  f1-score   ...
# 2                precision    recall  f1-score   ...
# 3                precision    recall  f1-score   ...
# 4                precision    recall  f1-score   ...

# %%
t.drop([ 'Time','Classification report'], axis=1, inplace=True)

# %%
t.head()
# Out:
#    Unnamed: 0                    Classifier  Accuracy
# 0           0              Ridge Classifier  0.822759
# 1           1           Logistic Regression  0.824263
# 2           2                    Perceptron  0.763888
# 3           3  Passive-Agressive Classifier  0.799148
# 4           4   Stochastic Gradient Descent  0.787437

# %%
t.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
t.head()
# Out:
#                      Classifier  Accuracy
# 0              Ridge Classifier  0.822759
# 1           Logistic Regression  0.824263
# 2                    Perceptron  0.763888
# 3  Passive-Agressive Classifier  0.799148
# 4   Stochastic Gradient Descent  0.787437

# %%
t.drop(t.index[0])
# Out:
#                       Classifier  Accuracy
# 1            Logistic Regression  0.823762
# 2                     Perceptron  0.757562
# 3   Passive-Agressive Classifier  0.764577
# 4    Stochastic Gradient Descent  0.813616
# 5                      LinearSVC  0.821319
# 6             L1 based LinearSVC  0.819252
# 7                            KNN  0.718732
# 8               Nearest Centroid  0.637815
# 9                 Multinomial NB  0.797332
# 10                  Bernoulli NB  0.793762
# 11                      Adaboost  0.702324

# %%
t
# Out:
#                       Classifier  Accuracy
# 0               Ridge Classifier  0.822759
# 1            Logistic Regression  0.824263
# 2                     Perceptron  0.763888
# 3   Passive-Agressive Classifier  0.799148
# 4    Stochastic Gradient Descent  0.787437
# 5                      LinearSVC  0.823260
# 6             L1 based LinearSVC  0.823448
# 7                            KNN  0.625540
# 8               Nearest Centroid  0.725496
# 9                 Multinomial NB  0.801528
# 10                  Bernoulli NB  0.799148
# 11                      Adaboost  0.702324

# %%
tt=t.sort_values(by='Accuracy', ascending=True)

# %%
tt
# Out:
#                       Classifier  Accuracy
# 7                            KNN  0.625540
# 11                      Adaboost  0.702324
# 8               Nearest Centroid  0.725496
# 2                     Perceptron  0.763888
# 4    Stochastic Gradient Descent  0.787437
# 3   Passive-Agressive Classifier  0.799148
# 10                  Bernoulli NB  0.799148
# 9                 Multinomial NB  0.801528
# 0               Ridge Classifier  0.822759
# 5                      LinearSVC  0.823260
# 6             L1 based LinearSVC  0.823448
# 1            Logistic Regression  0.824263

# %%
ttt=tt.drop(t.index[0])

# %%
ttt
# Out:
#                       Classifier  Accuracy
# 7                            KNN  0.625540
# 11                      Adaboost  0.702324
# 8               Nearest Centroid  0.725496
# 2                     Perceptron  0.763888
# 4    Stochastic Gradient Descent  0.787437
# 3   Passive-Agressive Classifier  0.799148
# 10                  Bernoulli NB  0.799148
# 9                 Multinomial NB  0.801528
# 5                      LinearSVC  0.823260
# 6             L1 based LinearSVC  0.823448
# 1            Logistic Regression  0.824263

# %%
plt.bar("Classifier","Accuracy", data =tt, color = "blue")
plt.xlabel("Classifier")
plt.xticks(rotation = 90)
plt.ylabel("Accuracy")
plt.title("Accuracy of Tf - idf  bigram")
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(14,12))
plt.plot("Classifier","Accuracy", data =tt, color = "blue")
plt.xlabel("Classifier")
plt.xticks(rotation = 90)
plt.ylabel("Accuracy")
plt.title("Accuracy of Tf - idf  bigram")
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(14,12))
plt.bar("Classifier","Accuracy", data =tt, color = "blue")
plt.xlabel("Classifier")
plt.xticks(rotation = 90)
plt.ylabel("Accuracy")
plt.title("Accuracy of Tf - idf  bigram")
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(14,12))
plt.bar("Classifier","Accuracy", data =tt, color = "blue")
plt.xlabel("Classifier")
plt.xticks(rotation = 90)
plt.ylabel("Accuracy")
plt.title("Accuracy of Tf - idf  bigram")
plt.show()
